# %% [markdown]
# <!-- Team 2 - Retail Project
#
# Domain: Retail - Sales Optimization
# Dataset: Kaggle - Superstore Sales Dataset
# Problem: Identify loss-making products and optimize sales.
# Roles: Team Lead, Data Engineer, Data Analyst, Statistician, ML Engineer, Business Analyst
# Repository Structure: data/, notebooks/, src/, reports/, README.md
# Workflow: JIRA Task → GitHub Branch → Commit → PR → Review → Merge
# Backlog: Cleaning, Missing Values, Distribution, Outliers, Category Analysis, Correlation, Insights -->
